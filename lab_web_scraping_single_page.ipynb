# %% [markdown]
# <a href="https://colab.research.google.com/github/Dankort/lab-web-scraping-single-page/blob/master/lab_web_scraping_single_page.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# Example on extracting the html page
r = requests.get('https://www.billboard.com/charts/hot-100/').content

# %%
soup = BeautifulSoup(r, 'html.parser')
print(soup.prettify())

# %%
soup.find_all("h3", attrs={"class": "c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"})

# %%
# Finding the songs and artists
artists = soup.find_all("span", attrs={"class": "c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"})
artists

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the Billboard Hot 100 chart
url = 'https://www.billboard.com/charts/hot-100'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Parse the HTML content of the webpage
soup = BeautifulSoup(response.content, 'html.parser')

# Find all elements containing song titles
song = soup.find_all("h3", attrs={"class": "c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"})

# Extract song titles from the elements
song_titles = [title.get_text(strip=True) for title in song]

# Find all elements containing artist names
artist_names = soup.find_all("span", attrs={"class": "c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"})

# Extract artist names from the elements
artists = [artist.get_text(strip=True) for artist in artist_names]

# Create a Pandas DataFrame from the extracted data
df = pd.DataFrame({
    'Song_Title': song_titles,
    'Artist': artists
})

# Display the DataFrame
df
# Out:
#              Song_Title                                             Artist
# 0          Lose Control                                        Teddy Swims
# 1      Beautiful Things                                       Benson Boone
# 2              Carnival  ¥$: Ye & Ty Dolla $ign Featuring Rich The Kid ...
# 3           Lovin On Me                                        Jack Harlow
# 4        Texas Hold 'Em                                            Beyonce
# ..                  ...                                                ...
# 94  Back Then Right Now                                      Tyler Hubbard
# 95           Tourniquet                                         Zach Bryan
# 96            Outskirts                                           Sam Hunt
# 97             Worth It                               Offset & Don Toliver
# 98             Fuk Sumn                             ¥$: Ye & Ty Dolla $ign
#
# [99 rows x 2 columns]
